# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/hackathon/hackathon')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import seaborn as sns
from google.colab import files

# %%
calls = pd.read_csv('call data.csv')
cust = pd.read_csv('customer data.csv')
reason = pd.read_csv('customer reason.csv')
sentiment = pd.read_csv('customer sentiment.csv')
test = pd.read_csv('test.csv')

data = {'Calls': calls, 'Customer': cust, 'Reason': reason, 'Sentiment Statistics': sentiment, 'Test': test}

# %%
# Convert the columns to datetime objects
calls['call_start_datetime'] = pd.to_datetime(calls['call_start_datetime'], format="%m/%d/%Y %H:%M")
calls['call_end_datetime'] = pd.to_datetime(calls['call_end_datetime'], format="%m/%d/%Y %H:%M")

# Add call_duration column to the dataset.
calls['call_duration'] = (calls['call_end_datetime'] - calls['call_start_datetime']).dt.total_seconds() // 60

# %%
calls.head()
# Out:
#       call_id  customer_id  agent_id call_start_datetime  \
# 0  4667960400   2033123310    963118 2024-07-31 23:56:00
# 1  1122072124   8186702651    519057 2024-08-01 00:03:00
# 2  6834291559   2416856629    158319 2024-07-31 23:59:00
# 3  2266439882   1154544516    488324 2024-08-01 00:05:00
# 4  1211603231   5214456437    721730 2024-08-01 00:04:00
#
#   agent_assigned_datetime   call_end_datetime  \
# 0           8/1/2024 0:03 2024-08-01 00:34:00
# 1           8/1/2024 0:06 2024-08-01 00:18:00
# 2           8/1/2024 0:07 2024-08-01 00:26:00
# 3           8/1/2024 0:10 2024-08-01 00:17:00
# 4           8/1/2024 0:14 2024-08-01 00:23:00
#
#                                      call_transcript  call_duration
# 0  \n\nAgent: Thank you for calling United Airlin...           38.0
# 1  \n\nAgent: Thank you for calling United Airlin...           15.0
# 2  \n\nAgent: Thank you for calling United Airlin...           27.0
# ...

# %%
reason.head()
# Out:
#       call_id primary_call_reason
# 0  4667960400   Voluntary  Cancel
# 1  1122072124             Booking
# 2  6834291559              IRROPS
# 3  2266439882             Upgrade
# 4  1211603231             Seating

# %%
calls.to_csv('updated_file_with_call_duration.csv', index=False)  # Save the DataFrame as a CSV file
files.download('updated_file_with_call_duration.csv')

# %%
for k,v in data.items():
  print(k)
  display(v.head(3))
  print(v.shape)
  print('\n')
  print('-'*200)
  print('\n')
# Out:
# Calls
#       call_id  customer_id  agent_id call_start_datetime  \
# 0  4667960400   2033123310    963118 2024-07-31 23:56:00
# 1  1122072124   8186702651    519057 2024-08-01 00:03:00
# 2  6834291559   2416856629    158319 2024-07-31 23:59:00
#
#   agent_assigned_datetime   call_end_datetime  \
# 0           8/1/2024 0:03 2024-08-01 00:34:00
# 1           8/1/2024 0:06 2024-08-01 00:18:00
# 2           8/1/2024 0:07 2024-08-01 00:26:00
#
#                                      call_transcript  call_duration
# 0  \n\nAgent: Thank you for calling United Airlin...           38.0
# 1  \n\nAgent: Thank you for calling United Airlin...           15.0
# 2  \n\nAgent: Thank you for calling United Airlin...           27.0
# (71810, 8)
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Customer
# ...

# %%
for k, v in data.items():
    print(k)
    missing_percentage = round((v.isna().sum() / v.shape[0]) * 100, 2)
    missing_percentage_df = pd.DataFrame(missing_percentage, columns=["% of missing values"])
    display(missing_percentage_df)
    print('\n')
    print('-' * 200)
    print('\n')
# Out:
# Calls
#                          % of missing values
# call_id                                  0.0
# customer_id                              0.0
# agent_id                                 0.0
# call_start_datetime                      0.0
# agent_assigned_datetime                  0.0
# call_end_datetime                        0.0
# call_transcript                          0.0
# call_duration                            0.0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Customer
#                   % of missing values
# customer_id                      0.00
# customer_name                    0.00
# elite_level_code                35.88
# ...
